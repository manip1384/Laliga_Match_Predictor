# %%
import pandas as pd

# %%
#read match data

# %%
matches = pd.read_csv("laliga_games.csv", index_col = 0)

# %%
matches.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result   GF   GA  \
# 1  2024-08-18  21:30  La Liga  Matchweek 1  Sun  Away      D  1.0  1.0
# 2  2024-08-25  17:00  La Liga  Matchweek 2  Sun  Home      W  3.0  0.0
# 3  2024-08-29  20:30  La Liga  Matchweek 3  Thu  Away      D  1.0  1.0
# 4  2024-09-01  21:30  La Liga  Matchweek 4  Sun  Home      W  2.0  0.0
# 5  2024-09-14  21:00  La Liga  Matchweek 5  Sat  Away      W  2.0  0.0
#
#         Opponent  ...  Match Report  Notes    Sh  SoT  Dist   FK PK PKatt  \
# 1       Mallorca  ...  Match Report    NaN  13.0  5.0  21.3  0.0  0     0
# 2     Valladolid  ...  Match Report    NaN  17.0  9.0  17.2  1.0  0     0
# 3     Las Palmas  ...  Match Report    NaN  24.0  7.0  18.0  1.0  1     1
# 4          Betis  ...  Match Report    NaN  21.0  6.0  16.3  0.0  1     1
# 5  Real Sociedad  ...  Match Report    NaN  14.0  4.0  19.4  1.0  2     2
#
#   Season         Team
# 1   2025  Real Madrid
# 2   2025  Real Madrid
# 3   2025  Real Madrid
# 4   2025  Real Madrid
# 5   2025  Real Madrid
#
# [5 rows x 28 columns]

# %%
matches.shape
# Out:
# (5684, 28)

# %%
#how many matches per team

# %%
matches["Team"].value_counts()
# Out:
# Team
# Real Madrid            285
# Barcelona              285
# Athletic Club          285
# Atletico Madrid        284
# Villarreal             284
# Valencia               284
# Real Sociedad          284
# Real Betis             284
# Celta Vigo             284
# Getafe                 284
# Sevilla                284
# Alaves                 246
# Espanyol               208
# Osasuna                208
# Levante                190
# Mallorca               171
# Girona                 170
# Valladolid             170
# Rayo Vallecano         170
# Eibar                  152
# Granada                152
# Cadiz                  152
# Leganes                132
# Elche                  114
# Las Palmas              94
# Almeria                 76
# Huesca                  76
# Deportivo La Coruna     38
# Malaga                  38
# Name: count, dtype: int64

# %%
#look at data types

# %%
matches.dtypes
# Out:
# Date              object
# Time              object
# Comp              object
# Round             object
# Day               object
# Venue             object
# Result            object
# GF               float64
# GA               float64
# Opponent          object
# xG               float64
# xGA              float64
# Poss             float64
# Attendance       float64
# Captain           object
# Formation         object
# Opp Formation     object
# Referee           object
# Match Report      object
# Notes            float64
# Sh               float64
# SoT              float64
# Dist             float64
# FK               float64
# PK                 int64
# PKatt              int64
# Season             int64
# Team              object
# dtype: object

# %%
#convert existing column to date time

# %%
matches["Date"] = pd.to_datetime(matches["Date"])

# %%
#conver home away to numeric. 0 away, 1 home

# %%
matches["venue_code"] = matches["Venue"].astype("category").cat.codes

# %%
#code for each opponent squad

# %%
matches["opp_code"] = matches["Opponent"].astype("category").cat.codes

# %%
#look at time of games and remove colon and minutes and just have hour

# %%
matches["hour"] = matches["Time"].str.replace(":.+", "", regex = True).astype("int")

# %%
#code each day of the week

# %%
matches["day_code"] = matches["Date"].dt.dayofweek

# %%
#win is a 1 and loss or draw is a 0

# %%
matches["target"] = (matches["Result"] == "W").astype("int")

# %%
# import model for machine learning

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#initialize class

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

# %%
#put anything before 2022 in training set

# %%
train = matches[matches["Date"] < '2022-01-01']

# %%
test = matches[matches["Date"] > '2022-01-01']

# %%
#create predictor list

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
#fit random forest model and predict target

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
#generate predictions

# %%
preds = rf.predict(test[predictors])

# %%
#determine accuracy of predictor

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6092105263157894

# %%
#in which situations was accuracy high and low

# %%
combined = pd.DataFrame(dict(actual = test["target"], prediction = preds))

# %%
#what happened when predicting win or loss

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction     0    1
# actual
# 0           1070  366
# 1            525  319

# %%
#revise accuraty metric

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.4656934306569343

# %%
#improve percision by making more predictors

# %%
grouped_matches = matches.groupby("Team")

# %%
group = grouped_matches.get_group("Real Madrid")

# %%
group
# Out:
#          Date   Time     Comp         Round  Day Venue Result   GF   GA  \
# 1  2024-08-18  21:30  La Liga   Matchweek 1  Sun  Away      D  1.0  1.0
# 2  2024-08-25  17:00  La Liga   Matchweek 2  Sun  Home      W  3.0  0.0
# 3  2024-08-29  20:30  La Liga   Matchweek 3  Thu  Away      D  1.0  1.0
# 4  2024-09-01  21:30  La Liga   Matchweek 4  Sun  Home      W  2.0  0.0
# 5  2024-09-14  21:00  La Liga   Matchweek 5  Sat  Away      W  2.0  0.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 53 2018-04-28  18:30  La Liga  Matchweek 35  Sat  Home      W  2.0  1.0
# 55 2018-05-06  20:45  La Liga  Matchweek 36  Sun  Away      D  2.0  2.0
# 56 2018-05-09  21:30  La Liga  Matchweek 34  Wed  Away      L  2.0  3.0
# 57 2018-05-12  20:45  La Liga  Matchweek 37  Sat  Home      W  6.0  0.0
# 58 2018-05-19  20:45  La Liga  Matchweek 38  Sat  Away      D  2.0  2.0
#
#          Opponent  ...   FK  PK  PKatt  Season         Team venue_code  \
# 1        Mallorca  ...  0.0   0      0    2025  Real Madrid          0
# 2      Valladolid  ...  1.0   0      0    2025  Real Madrid          1
# 3      Las Palmas  ...  1.0   1      1    2025  Real Madrid          0
# 4           Betis  ...  0.0   1      1    2025  Real Madrid          1
# 5   Real Sociedad  ...  1.0   2      2    2025  Real Madrid          0
# ..            ...  ...  ...  ..    ...     ...          ...        ...
# 53        Leganés  ...  1.0   0      0    2018  Real Madrid          1
# 55      Barcelona  ...  1.0   0      0    2018  Real Madrid          0
# 56        Sevilla  ...  2.0   1      2    2018  Real Madrid          0
# 57     Celta Vigo  ...  1.0   0      0    2018  Real Madrid          1
# 58     Villarreal  ...  0.0   0      0    2018  Real Madrid          0
#
#    opp_code hour day_code  target
# 1        19   21        6       0
# 2        27   17        6       1
# 3        16   20        3       0
# 4         5   21        6       1
# 5        24   21        5       1
# ..      ...  ...      ...     ...
# 53       17   18        5       1
# 55        4   20        6       0
# 56       25   21        2       0
# 57        6   20        5       1
# 58       28   20        5       0
#
# [285 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("Date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "PK", "PKatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['GF_rolling',
#  'GA_rolling',
#  'Sh_rolling',
#  'SoT_rolling',
#  'Dist_rolling',
#  'PK_rolling',
#  'PKatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          Date   Time     Comp         Round  Day Venue Result   GF   GA  \
# 7  2017-09-17  20:45  La Liga   Matchweek 4  Sun  Away      W  3.0  1.0
# 8  2017-09-20  22:00  La Liga   Matchweek 5  Wed  Home      L  0.0  1.0
# 9  2017-09-23  16:15  La Liga   Matchweek 6  Sat  Away      W  2.0  1.0
# 11 2017-10-01  20:45  La Liga   Matchweek 7  Sun  Home      W  2.0  0.0
# 12 2017-10-14  16:15  La Liga   Matchweek 8  Sat  Away      W  2.0  1.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 20 2024-12-04  21:00  La Liga  Matchweek 19  Wed  Away      L  1.0  2.0
# 21 2024-12-07  21:00  La Liga  Matchweek 16  Sat  Away      W  3.0  0.0
# 23 2024-12-14  21:00  La Liga  Matchweek 17  Sat  Away      D  3.0  3.0
# 24 2024-12-22  16:15  La Liga  Matchweek 18  Sun  Home      W  4.0  2.0
# 25 2025-01-03  21:00  La Liga  Matchweek 12  Fri  Away      W  2.0  1.0
#
#           Opponent  ...  hour  day_code  target  GF_rolling GA_rolling  \
# 7    Real Sociedad  ...    20         6       1    2.000000   1.000000
# 8            Betis  ...    22         2       0    2.000000   1.333333
# 9           Alavés  ...    16         5       1    1.333333   1.000000
# 11        Espanyol  ...    20         6       1    1.666667   1.000000
# 12          Getafe  ...    16         5       1    1.333333   0.666667
# ..             ...  ...   ...       ...     ...         ...        ...
# 20   Athletic Club  ...    21         2       0    3.000000   0.000000
# 21          Girona  ...    21         5       1    2.000000   0.666667
# 23  Rayo Vallecano  ...    21         5       0    2.000000   0.666667
# 24         Sevilla  ...    16         6       1    2.333333   1.666667
# 25        Valencia  ...    21         4       1    3.333333   1.666667
#
#    Sh_rolling SoT_rolling Dist_rolling PK_rolling  PKatt_rolling
# 7   18.666667    8.000000    17.433333   0.000000       0.000000
# 8   19.333333    7.333333    16.333333   0.000000       0.000000
# 9   21.000000    7.333333    15.533333   0.000000       0.000000
# 11  22.000000    6.333333    16.066667   0.000000       0.000000
# 12  23.666667    7.000000    17.033333   0.000000       0.000000
# ..        ...         ...          ...        ...            ...
# 20  15.333333    6.333333    16.133333   0.333333       0.333333
# 21  12.333333    5.000000    16.900000   0.333333       0.666667
# 23  10.333333    4.666667    18.133333   0.333333       0.666667
# 24  10.666667    5.666667    19.466667   0.000000       0.333333
# 25  13.000000    6.666667    18.500000   0.000000       0.000000
#
# [282 rows x 40 columns]

# %%
#apply this to all matches

# %%
matches_rolling = matches.groupby("Team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                     Date   Time     Comp         Round  Day Venue Result   GF  \
# Team
# Alaves     3  2017-09-17  12:00  La Liga   Matchweek 4  Sun  Home      L  0.0
#            4  2017-09-20  21:00  La Liga   Matchweek 5  Wed  Away      L  0.0
#            5  2017-09-23  16:15  La Liga   Matchweek 6  Sat  Home      L  1.0
#            6  2017-09-30  18:30  La Liga   Matchweek 7  Sat  Away      W  2.0
#            7  2017-10-14  18:30  La Liga   Matchweek 8  Sat  Home      L  0.0
# ...                  ...    ...      ...           ...  ...   ...    ...  ...
# Villarreal 14 2024-12-01  14:00  La Liga  Matchweek 15  Sun  Home      D  2.0
#            16 2024-12-08  16:15  La Liga  Matchweek 16  Sun  Away      L  0.0
#            17 2024-12-15  18:30  La Liga  Matchweek 17  Sun  Home      L  1.0
#            18 2024-12-18  21:30  La Liga  Matchweek 12  Wed  Home      D  1.0
#            19 2024-12-22  18:30  La Liga  Matchweek 18  Sun  Away      W  5.0
#
#                 GA        Opponent  ...  hour  day_code  target  GF_rolling  \
# Team                                ...
# Alaves     3   3.0      Villarreal  ...    12         6       0    0.000000
#            4   1.0       La Coruña  ...    21         2       0    0.000000
#            5   2.0     Real Madrid  ...    16         5       0    0.000000
#            6   0.0         Levante  ...    18         5       1    0.333333
#            7   2.0   Real Sociedad  ...    18         5       0    1.000000
# ...            ...             ...  ...   ...       ...     ...         ...
# Villarreal 14  2.0          Girona  ...    14         6       0    2.333333
#            16  2.0   Athletic Club  ...    16         6       0    2.333333
#            17  2.0           Betis  ...    18         6       0    1.333333
#            18  1.0  Rayo Vallecano  ...    21         2       0    1.000000
#            19  2.0         Leganés  ...    18         6       1    0.666667
#
#               GA_rolling Sh_rolling SoT_rolling Dist_rolling PK_rolling  \
# Team
# Alaves     3    1.333333   8.000000    3.000000    20.066667   0.000000
#            4    2.000000  10.666667    2.333333    20.533333   0.000000
#            5    1.666667   9.666667    2.666667    20.200000   0.000000
#            6    2.000000  10.666667    2.666667    21.233333   0.000000
#            7    1.000000   8.000000    3.000000    17.633333   0.000000
# ...                  ...        ...         ...          ...        ...
# Villarreal 14   1.000000  16.000000    5.666667    17.166667   0.666667
#            16   1.333333  13.333333    4.000000    16.400000   0.666667
#            17   2.000000  13.000000    3.666667    16.166667   0.333333
#            18   2.000000  13.666667    2.666667    15.533333   0.000000
#            19   1.666667  14.000000    3.000000    16.366667   0.000000
#
#                PKatt_rolling
# Team
# Alaves     3        0.333333
#            4        0.000000
#            5        0.000000
#            6        0.000000
#            7        0.000000
# ...                      ...
# Villarreal 14       0.666667
#            16       0.666667
#            17       0.333333
#            18       0.000000
#            19       0.000000
#
# [5591 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('Team')

# %%
matches_rolling
# Out:
#          Date   Time     Comp         Round  Day Venue Result   GF   GA  \
# 3  2017-09-17  12:00  La Liga   Matchweek 4  Sun  Home      L  0.0  3.0
# 4  2017-09-20  21:00  La Liga   Matchweek 5  Wed  Away      L  0.0  1.0
# 5  2017-09-23  16:15  La Liga   Matchweek 6  Sat  Home      L  1.0  2.0
# 6  2017-09-30  18:30  La Liga   Matchweek 7  Sat  Away      W  2.0  0.0
# 7  2017-10-14  18:30  La Liga   Matchweek 8  Sat  Home      L  0.0  2.0
# ..        ...    ...      ...           ...  ...   ...    ...  ...  ...
# 14 2024-12-01  14:00  La Liga  Matchweek 15  Sun  Home      D  2.0  2.0
# 16 2024-12-08  16:15  La Liga  Matchweek 16  Sun  Away      L  0.0  2.0
# 17 2024-12-15  18:30  La Liga  Matchweek 17  Sun  Home      L  1.0  2.0
# 18 2024-12-18  21:30  La Liga  Matchweek 12  Wed  Home      D  1.0  1.0
# 19 2024-12-22  18:30  La Liga  Matchweek 18  Sun  Away      W  5.0  2.0
#
#           Opponent  ...  hour  day_code  target  GF_rolling GA_rolling  \
# 3       Villarreal  ...    12         6       0    0.000000   1.333333
# 4        La Coruña  ...    21         2       0    0.000000   2.000000
# 5      Real Madrid  ...    16         5       0    0.000000   1.666667
# 6          Levante  ...    18         5       1    0.333333   2.000000
# 7    Real Sociedad  ...    18         5       0    1.000000   1.000000
# ..             ...  ...   ...       ...     ...         ...        ...
# 14          Girona  ...    14         6       0    2.333333   1.000000
# 16   Athletic Club  ...    16         6       0    2.333333   1.333333
# 17           Betis  ...    18         6       0    1.333333   2.000000
# 18  Rayo Vallecano  ...    21         2       0    1.000000   2.000000
# 19         Leganés  ...    18         6       1    0.666667   1.666667
#
#    Sh_rolling SoT_rolling Dist_rolling PK_rolling  PKatt_rolling
# 3    8.000000    3.000000    20.066667   0.000000       0.333333
# 4   10.666667    2.333333    20.533333   0.000000       0.000000
# 5    9.666667    2.666667    20.200000   0.000000       0.000000
# 6   10.666667    2.666667    21.233333   0.000000       0.000000
# 7    8.000000    3.000000    17.633333   0.000000       0.000000
# ..        ...         ...          ...        ...            ...
# 14  16.000000    5.666667    17.166667   0.666667       0.666667
# 16  13.333333    4.000000    16.400000   0.666667       0.666667
# 17  13.000000    3.666667    16.166667   0.333333       0.333333
# 18  13.666667    2.666667    15.533333   0.000000       0.000000
# 19  14.000000    3.000000    16.366667   0.000000       0.000000
#
# [5591 rows x 40 columns]

# %%
#unique values for each index

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
#make new predictions

# %%
def make_predictions(data, predictors):
    train = data[data["Date"] < '2022-01-01']
    test = data[data["Date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual = test["target"], predicted = preds), index = test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5570469798657718

# %%
combined
# Out:
#       actual  predicted
# 167        0          0
# 168        0          0
# 169        0          0
# 170        0          0
# 171        0          0
# ...      ...        ...
# 5586       0          1
# 5587       0          0
# 5588       0          1
# 5589       0          0
# 5590       1          0
#
# [2274 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["Date", "Team", "Opponent", "Result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       Date        Team        Opponent Result
# 167        0          0 2022-01-02      Alaves   Real Sociedad      D
# 168        0          0 2022-01-09      Alaves   Athletic Club      D
# 169        0          0 2022-01-18      Alaves           Betis      L
# 170        0          0 2022-01-23      Alaves       Barcelona      L
# 171        0          0 2022-02-05      Alaves           Elche      L
# ...      ...        ...        ...         ...             ...    ...
# 5586       0          1 2024-12-01  Villarreal          Girona      D
# 5587       0          0 2024-12-08  Villarreal   Athletic Club      L
# 5588       0          1 2024-12-15  Villarreal           Betis      L
# 5589       0          0 2024-12-18  Villarreal  Rayo Vallecano      D
# 5590       1          0 2024-12-22  Villarreal         Leganés      W
#
# [2274 rows x 6 columns]

# %%
#combine home and away perdictions.

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Alavés" : "Alaves",
    "Cádiz" : "Cadiz",
    "Atlético Madrid" : "Atletico Madrid",
    "Betis" : "Real Betis",
    "Málaga" : "Malaga",
    "Leganés" : "Leganes",
    "La Coruña" : "Deportivo La Coruna",
    "Alméria" : "Almeria",
    
    
}
mapping = MissingDict(**map_values)

# %%
mapping["La Coruña"]
# Out:
# 'Deportivo La Coruna'

# %%
combined["new_team"] = combined["Team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       Date        Team        Opponent Result  \
# 167        0          0 2022-01-02      Alaves   Real Sociedad      D
# 168        0          0 2022-01-09      Alaves   Athletic Club      D
# 169        0          0 2022-01-18      Alaves           Betis      L
# 170        0          0 2022-01-23      Alaves       Barcelona      L
# 171        0          0 2022-02-05      Alaves           Elche      L
# ...      ...        ...        ...         ...             ...    ...
# 5586       0          1 2024-12-01  Villarreal          Girona      D
# 5587       0          0 2024-12-08  Villarreal   Athletic Club      L
# 5588       0          1 2024-12-15  Villarreal           Betis      L
# 5589       0          0 2024-12-18  Villarreal  Rayo Vallecano      D
# 5590       1          0 2024-12-22  Villarreal         Leganés      W
#
#         new_team
# 167       Alaves
# 168       Alaves
# 169       Alaves
# 170       Alaves
# 171       Alaves
# ...          ...
# 5586  Villarreal
# 5587  Villarreal
# 5588  Villarreal
# 5589  Villarreal
# 5590  Villarreal
#
# [2274 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["Date", "new_team"], right_on=["Date", "Opponent"])

# %%
merged
# Out:
#       actual_x  predicted_x       Date         Team_x      Opponent_x  \
# 0            1            0 2022-01-03  Athletic Club         Osasuna
# 1            0            0 2022-01-09  Athletic Club          Alavés
# 2            1            0 2022-01-23  Athletic Club  Rayo Vallecano
# 3            1            1 2022-02-07  Athletic Club        Espanyol
# 4            0            0 2022-02-14  Athletic Club        Mallorca
# ...        ...          ...        ...            ...             ...
# 1773         0            1 2024-12-01     Villarreal          Girona
# 1774         0            0 2024-12-08     Villarreal   Athletic Club
# 1775         0            1 2024-12-15     Villarreal           Betis
# 1776         0            0 2024-12-18     Villarreal  Rayo Vallecano
# 1777         1            0 2024-12-22     Villarreal         Leganés
#
#      Result_x     new_team_x  actual_y  predicted_y          Team_y  \
# 0           W  Athletic Club         0            0         Osasuna
# 1           D  Athletic Club         0            0          Alaves
# 2           W  Athletic Club         0            0  Rayo Vallecano
# 3           W  Athletic Club         0            0        Espanyol
# 4           L  Athletic Club         1            0        Mallorca
# ...       ...            ...       ...          ...             ...
# 1773        D     Villarreal         0            0          Girona
# 1774        L     Villarreal         1            0   Athletic Club
# 1775        L     Villarreal         1            0      Real Betis
# 1776        D     Villarreal         0            0  Rayo Vallecano
# 1777        W     Villarreal         0            0         Leganes
#
#          Opponent_y Result_y      new_team_y
# 0     Athletic Club        L         Osasuna
# 1     Athletic Club        D          Alaves
# 2     Athletic Club        L  Rayo Vallecano
# 3     Athletic Club        L        Espanyol
# 4     Athletic Club        W        Mallorca
# ...             ...      ...             ...
# 1773     Villarreal        D          Girona
# 1774     Villarreal        W   Athletic Club
# 1775     Villarreal        W      Real Betis
# 1776     Villarreal        D  Rayo Vallecano
# 1777     Villarreal        L         Leganes
#
# [1778 rows x 13 columns]

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    188
# 0    155
# Name: count, dtype: int64
